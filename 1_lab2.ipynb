# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
open_api_key  = os.getenv("OPENAI_API_KEY")
deep_seek_api_key = os.getenv("DEEP_SEEK_API_KEY")

request ="Please come up with a challenging Physics question for IIT JEE exam. Only Question no answer"
message  = [{"role":"user", "content": request}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=message
)
question=response.choices[0].message.content
print(question)
# Out:
# A block of mass \( m \) is placed on a frictionless incline of angle \( \theta \) with the horizontal. The incline is fixed to a spring with spring constant \( k \), which is initially unstressed. The block is released from rest at a height \( h \) above the base of the incline.
#
# 1. Determine the maximum compression of the spring when the block descends and comes to a momentary stop.
# 2. Assume the system is isolated and energy is conserved throughout the motion.
#
# You may neglect any effects due to air resistance.
#
# (Note: You should express your answer in terms of \( m \), \( g \), \( k \), and \( \theta \).)

# %%
compititor = [];
answer = [];
message =  [{"role":"user", "content": question}]

# %%
deepseekclient = OpenAI(api_key=deep_seek_api_key, base_url="https://api.deepseek.com/v1")
models = deepseekclient.models.list()
for model in models:
    print(model.id)
# Out:
# deepseek-chat
# deepseek-reasoner

# %%
model_name ="gpt-4o-mini"
response = openai.chat.completions.create(
    model=model_name,
    messages=message
)
answer = response.choices[0].message.content
display(Markdown(answer))
compititor.append(model_name)
compititor.append(answer)
# Out:
# **Question:**
#
# A block of mass \( m \) is placed on a frictionless inclined plane that makes an angle \( \theta \) with the horizontal. The inclined plane is able to accelerate with a constant acceleration \( a \) horizontally to the right.
#
# 1. Determine the conditions under which the block will remain at rest relative to the inclined plane.
# 2. Calculate the normal force acting on the block by the inclined plane, expressed in terms of \( m \), \( g \), \( \theta \), and \( a \).
# 3. If the angle \( \theta \) is changed and the block begins to slide down the incline, find an expression for the acceleration of the block down the incline in terms of \( g \), \( \theta \), and \( a \).
#
# *Assume \( g \) is the acceleration due to gravity and is acting downwards.*

# %%
api_key = os.getenv("GEMINI_API_KEY") # Note: Usually named GOOGLE_API_KEY for this SDK
model_name= ""
